# %%
from tkinter import *
from tkinter import messagebox
import numpy as np
import import_ipynb
import neuralNetworks


def click(button):
    mytext = button.cget('text')

    if mytext == "-1":
        button.configure(text="1")
        button.configure(bg="#ADD8E6")
    if mytext == "1":
        button.configure(text="-1")
        button.configure(bg="#FFA500")


        
        
def perdict():
    current = [int(button00.cget('text')), int(button01.cget('text')), int(button02.cget('text')), 
            int(button03.cget('text')), int(button04.cget('text')),
            int(button10.cget('text')), int(button11.cget('text')), int(button12.cget('text')), 
                int(button13.cget('text')), int(button14.cget('text')),
            int(button20.cget('text')), int(button21.cget('text')), int(button22.cget('text')), 
                int(button23.cget('text')), int(button24.cget('text')),
            int(button30.cget('text')), int(button31.cget('text')), int(button32.cget('text')), 
                int(button33.cget('text')), int(button34.cget('text')),
            int(button40.cget('text')), int(button41.cget('text')), int(button42.cget('text')), 
                int(button43.cget('text')), int(button44.cget('text'))]
    perdict_from_hebb = neuralNetworks.calculate_output(np.array([current]),
                        weightsHebb, biasHebb)
    if perdict_from_hebb == 1:
        this_is_X()
    else:
        this_is_O()
#     this_is_X() if neuralNetworks.calculate_output(np.array([current]), weightsHebb, biasHebb)
#           == 1 else this_is_O()

    
    
def this_is_X():
    res = messagebox.showinfo('Response','This is X')


def this_is_O():
    res = messagebox.showinfo('Response','This is O')

    
    
def reset_the_buttens():
    b = (button00, button01, button02, button03, button04, button10, button11, button12, button13, button14, button20, button21,
         button22, button23, button24, button30, button31, button32, button33, button34, button40, button41, button42, button43, button44)
    for i in b:
        i.config(text="-1")
        i.config(bg="#FFA500")


window = Tk()

# -------------- creat buttons of row one ---------------

button00 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button00), bg="#FFA500")
button00.grid(row=0, column=0)

button01 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button01), bg="#FFA500")
button01.grid(row=0, column=1)

button02 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button02), bg="#FFA500")
button02.grid(row=0, column=2)

button03 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button03), bg="#FFA500")
button03.grid(row=0, column=3)

button04 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button04), bg="#FFA500")
button04.grid(row=0, column=4)

# -------------- creat buttons of row two ---------------

button10 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button10), bg="#FFA500")
button10.grid(row=1, column=0)

button11 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button11), bg="#FFA500")
button11.grid(row=1, column=1)

button12 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button12), bg="#FFA500")
button12.grid(row=1, column=2)

button13 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button13), bg="#FFA500")
button13.grid(row=1, column=3)

button14 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button14), bg="#FFA500")
button14.grid(row=1, column=4)

# -------------- creat buttons of row three ---------------

button20 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button20), bg="#FFA500")
button20.grid(row=2, column=0)

button21 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button21), bg="#FFA500")
button21.grid(row=2, column=1)

button22 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button22), bg="#FFA500")
button22.grid(row=2, column=2)

button23 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button23), bg="#FFA500")
button23.grid(row=2, column=3)

button24 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button24), bg="#FFA500")
button24.grid(row=2, column=4)


# -------------- creat buttons of row four ---------------

button30 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button30), bg="#FFA500")
button30.grid(row=3, column=0)

button31 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button31), bg="#FFA500")
button31.grid(row=3, column=1)

button32 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button32), bg="#FFA500")
button32.grid(row=3, column=2)

button33 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button33), bg="#FFA500")
button33.grid(row=3, column=3)

button34 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button34), bg="#FFA500")
button34.grid(row=3, column=4)

button35 = Button(window, font=("IranSans", 20, "bold"), padx=36, bd=8, fg="black",
                  text="Reset", command=reset_the_buttens)
button35.grid(row=3, column=5)


# -------------- creat buttons of row five ---------------

button40 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button40), bg="#FFA500")
button40.grid(row=4, column=0)

button41 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button41), bg="#FFA500")
button41.grid(row=4, column=1)

button42 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button42), bg="#FFA500")
button42.grid(row=4, column=2)

button43 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button43), bg="#FFA500")
button43.grid(row=4, column=3)

button44 = Button(window, font=("IranSans", 20, "bold"), padx=22, pady=10, bd=8, fg="black",
                  text="-1", command=lambda: click(button44), bg="#FFA500")
button44.grid(row=4, column=4)

button45 = Button(window, font=("IranSans", 20, "bold"), padx=36, bd=8, fg="black",
                  text="Perdict", command=perdict)
button45.grid(row=4, column=5)

weightsHebb, biasHebb = neuralNetworks.hebb()

window.mainloop()
